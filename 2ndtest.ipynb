# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreeranga1/DeepLearningPractice/blob/main/2ndtest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
import tensorflow as tf
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow.keras import layers
import PIL.Image as Image

# %%
covid = "/content/trainData/covid/"
non_covid = "/content/trainData/non covid/"

# %%
def load_img(path):
    image = cv2.imread(path)
    image = cv2.resize(image, (224, 224))
    return image[...,::-1]

# %%
import pathlib
data_dir = pathlib.Path("/content/trainData/")
data_dir
# Out:
# PosixPath('/content/trainData')

# %%
list(data_dir.glob('*.*'))[:5]
# Out:
# [PosixPath('/content/trainData/.ipynb_checkpoints')]

# %%
flowers_images_dict['covid'][0]
# Out:
# PosixPath('/content/trainData/covid/2020.03.01.20029769-p21-73_4.png')

# %%
img=cv2.imread(str(covid_images_dict['covid'][1]))

# %%
def load_img(path):
    image = cv2.imread(path)
    image = cv2.resize(image, (224, 224))
#     print(labels)
    return image[...,::-1]

# %%
plt.imshow(load_img(str(covid_images_dict['covid'][1])), cmap='gray')

# %%
categories = ["covid" , "non covid"]

for category in categories:
    path = "/content/trainData/"+category+"/"
    for img in list(pathlib.Path(path).glob("*.*")):
        img_array = cv2.imread(str(img), cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_array, cmap="gray")
        # plt.imshow(img_array, cmap= plt.cm.binary)
        plt.show()
        print(category)
        break
    break
# Out:
# covid

# %%
training_data = []
IMG_SIZE = 224

## This means 0 will indicate Real facial Images and 1 to Fake facial Images.

categories = ["covid" , "non covid"]

def create_training_data():
    for category in categories:
        path = "/content/trainData/"+category+"/"
        class_num = categories.index(category)
        for img in list(pathlib.Path(path).glob("*.*")):
            try:
                img_array = cv2.imread(str(img), cv2.IMREAD_UNCHANGED)
                new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                training_data.append([new_array,class_num])
            except:
                pass
create_training_data()
